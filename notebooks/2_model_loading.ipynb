# %%
# %%writefile requirements.txt
# transformers==4.57.3
# accelerate
# bitsandbytes
# Out:
# Writing requirements.txt

# %%
! python -m pip download --destination-directory . -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 92.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 27.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 102.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 38.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.2/507.2 kB 29.9 MB/s eta 0:00:00
# ...

# %%
from peft import PeftModel, PeftConfig
from transformers import AutoModel, AutoTokenizer, AutoConfig

ADAPTER_REPO = "bheshaj/deberta-v3-base-pairwise-sequence-classifier-peft-finetuned"
BACKBONE_MODEL_REPO = "microsoft/deberta-v3-base"

adapter_config = PeftConfig.from_pretrained(ADAPTER_REPO)
backbone = AutoModel.from_pretrained(BACKBONE_MODEL_REPO)
tokenizer = AutoTokenizer.from_pretrained(adapter_config.base_model_name_or_path)
base_model_config = AutoConfig.from_pretrained(adapter_config.base_model_name_or_path, trust_remote_code=True)
base_model = AutoModel.from_pretrained(adapter_config.base_model_name_or_path, config=base_model_config, trust_remote_code=True)

# Load the Lora model
inference_model = PeftModel.from_pretrained(base_model, ADAPTER_REPO)
# Out:
# 2025-12-29 00:16:59.533377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766967419.740991      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766967419.803266      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766967420.308888      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#inference_model.save_pretrained('deberta-v3-base-pairwise-sequence-classifier-peft-finetuned')
#base_model.save_pretrained('deberta-v3-base-pairwise-sequence-classifier-base')
#backbone.save_pretrained('deberta-v3-base')
#tokenizer.save_pretrained('deberta-v3-base-pairwise-sequence-classifier-tokenizer')

# %%
tokenizer.save_pretrained('deberta-v3-base-pairwise-sequence-classifier-tokenizer')
# Out:
# ('deberta-v3-base-pairwise-sequence-classifier-tokenizer/tokenizer_config.json',
#  'deberta-v3-base-pairwise-sequence-classifier-tokenizer/special_tokens_map.json',
#  'deberta-v3-base-pairwise-sequence-classifier-tokenizer/spm.model',
#  'deberta-v3-base-pairwise-sequence-classifier-tokenizer/added_tokens.json',
#  'deberta-v3-base-pairwise-sequence-classifier-tokenizer/tokenizer.json')

# %%
from huggingface_hub import snapshot_download

local_path = snapshot_download(
    repo_id="microsoft/deberta-v3-base",
    local_dir="deberta-v3-base",
    local_dir_use_symlinks=False
)

print(local_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# rust_model.ot:   0%|          | 0.00/742M [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/736M [00:00<?, ?B/s]
# /kaggle/working/deberta-v3-base

# %%
from huggingface_hub import snapshot_download

local_path = snapshot_download(
    repo_id="bheshaj/deberta-v3-base-pairwise-sequence-classifier-peft-finetuned",
    local_dir="deberta-v3-base-pairwise-sequence-classifier-peft-finetuned",
    local_dir_use_symlinks=False
)

print(local_path)
# Out:
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# README.md: 0.00B [00:00, ?B/s]
# training_args.bin:   0%|          | 0.00/5.62k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/970 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# /kaggle/working/deberta-v3-base-pairwise-sequence-classifier-peft-finetuned

# %%
from huggingface_hub import snapshot_download

local_path = snapshot_download(
    repo_id="bheshaj/deberta-v3-base-pairwise-sequence-classifier",
    local_dir="deberta-v3-base-pairwise-sequence-classifier-base",
    local_dir_use_symlinks=False
)

print(local_path)
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# training_args.bin:   0%|          | 0.00/5.62k [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# /kaggle/working/deberta-v3-base-pairwise-sequence-classifier-base
